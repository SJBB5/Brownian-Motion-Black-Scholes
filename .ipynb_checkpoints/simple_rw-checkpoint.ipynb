# %% [markdown]
# We can generally define a random walk as
#
# $$
# S_{n+1} = S_n + X_n, \ \   n = 0,1,...
# $$
# where $X_i$ are iid random variables. The simplest manifestation of this process can be implemented by using a Bernoulli distribution with $p = 0.5$ for the $X_i$.\\
# \\
# Another slightly more complicated way is to define a sample space for movement as
# $$
# C = \{L_1, L_2\}
# $$
# Where $L_1$ and $L_2$ correspond to traveling a certain distance, and there are $p_1$ and $p_2$, which are the probabilities of traveling the corresponding distances and $p_1 + p_2 = 1$. We can derive,
# $$
# \begin{aligned}
# E[X_i] &= L_1 p_1 + L_2 p_2 \\
# \operatorname{Var}[X] &= p_1 p_2 (L_1 - L_2)^2
# \end{aligned}
# $$
# First, we will simulate the simplest case where $L_1 = -1$ and $L_2 = 1$, with equal (p=0.5) probability.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd

n_paths = 25
n_steps = 100

rng = np.random.default_rng()

steps = rng.choice([-1.0, 1.0], size=(n_paths, n_steps)) # choice uses default of p = 0.5
paths = np.c_[np.zeros(n_paths), steps.cumsum(axis=1)] # Joins starting column and cumult increase arrays

t = np.arange(n_steps + 1)

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(t, paths.T, linewidth=1)
# Out:
# [<matplotlib.lines.Line2D at 0x13267e720>,
#  <matplotlib.lines.Line2D at 0x13269ab70>,
#  <matplotlib.lines.Line2D at 0x13269ac90>,
#  <matplotlib.lines.Line2D at 0x13269adb0>,
#  <matplotlib.lines.Line2D at 0x13269aed0>,
#  <matplotlib.lines.Line2D at 0x13269aff0>,
#  <matplotlib.lines.Line2D at 0x13269b110>,
#  <matplotlib.lines.Line2D at 0x13267d850>,
#  <matplotlib.lines.Line2D at 0x13269b320>,
#  <matplotlib.lines.Line2D at 0x13269b440>,
#  <matplotlib.lines.Line2D at 0x13269b560>,
#  <matplotlib.lines.Line2D at 0x13269b680>,
#  <matplotlib.lines.Line2D at 0x13269b7a0>,
#  <matplotlib.lines.Line2D at 0x13269b8c0>,
#  <matplotlib.lines.Line2D at 0x13269b9e0>,
#  <matplotlib.lines.Line2D at 0x13269bb00>,
#  <matplotlib.lines.Line2D at 0x13236fc50>,
#  <matplotlib.lines.Line2D at 0x13269bd10>,
#  <matplotlib.lines.Line2D at 0x13267f7d0>,
#  <matplotlib.lines.Line2D at 0x13269bf20>,
#  <matplotlib.lines.Line2D at 0x13267f1d0>,
#  <matplotlib.lines.Line2D at 0x132500f50>,
#  <matplotlib.lines.Line2D at 0x1326cc230>,
#  <matplotlib.lines.Line2D at 0x13269a120>,
#  <matplotlib.lines.Line2D at 0x1326cc350>]
