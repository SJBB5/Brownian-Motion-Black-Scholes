# %% [markdown]
# We covered GBM using the equation,
#
# $$dS_t = \mu S_t dt + \sigma S_t dW_t$$
#
# The famous black scholes equation is
#
# $$
# \frac{\partial V}{\partial t}
# +\frac{1}{2}\sigma^{2} S^{2} \frac{\partial^{2} V}{\partial S^{2}}
# +r S \frac{\partial V}{\partial S}
# - r V = 0,
# \qquad
# V(S,T)=\max(S-K,0).
# $$
#
# and works under the assumptions that stocks follow Geometric Brownian Motion.

# %%
import numpy as np
from scipy.stats import norm

# defining variables
r = 0.01
S = 30
K = 40
T = 240/365
sigma = 0.3

def blackScholes(r, S, K, T, sigma, type="C"):
    # Calculate BS option price for a call/put.

# %% [markdown]
# European vs american options pricing and expire time.
